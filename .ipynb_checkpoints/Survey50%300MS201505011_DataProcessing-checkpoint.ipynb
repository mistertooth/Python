# %%
from IPython.display import HTML

HTML('''<script>
code_show=true;
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
}
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# ### 20160425
# ### 4 month data between nov 2015 and feb 2016
# ### all formats
# ### >=50% and 300ms
# ### inscreen left outer join delivery
# ### adspaceid, originaladid, surveyadid, formt, market, platform, devicemodel, platformtype, os, adspaceid,premlevel, click, interaction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# this allows plots to appear directly in the notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# pip install patsy
# pip install statsmodels
import statsmodels.formula.api as smf
# Set ipython's max row display
pd.set_option('display.max_row', 1000)

# Set iPython's max column width to 50
pd.set_option('display.max_columns', 50)

from IPython.core.display import display, HTML

# %%
# define url
url_0511 = '/Users/shaokuixing/Desktop/whatever/survey50_300_left20160426.csv'

# read csv file without header
rawData = pd.read_csv(url_0511, sep='\t', thousands = '.', decimal =',', header=None)

# add column label
rawData.columns = ['surveyid', 'originaladid','surveyadid','format','market','originaladstarttime',
                   'originaladendtime','surveyresponcetime','uid','answersetid','answerid','questionid',
                   'questiontext','optionid','optiontext','iscomplete','isrefgroup','platformid',
                   'devicemodelid','platformtypeid','osid','adspaceid','premlevel','latestimptime','earliestimptime',
                   'deliveredimp','imp30pct300ms','click','1stinteraction','imp0pct0ms', 'viewtime50pct300ms'                  
                  ]
# see first 2 rows
rawData.head(2)
# Out:
#    surveyid  originaladid  surveyadid format market  originaladstarttime  \
# 0       291         36430       36355  swipe     FI  2015-11-01 23:00:00
# 1       291         36430       36355  swipe     FI  2015-11-01 23:00:00
#
#      originaladendtime   surveyresponcetime                  uid  answersetid  \
# 0  2015-11-22 22:59:00  2015-11-04 20:31:57  5857845920412998079       218047
# 1  2015-11-22 22:59:00  2015-11-05 09:50:28   388034536731279936       218979
#
#    answerid  questionid                                       questiontext  \
# 0    595092          86  Is the ad interesting for you?<br><span class=...
# 1    597580          83  Next time you are about to use/purchase §categ...
#
#    optionid optiontext iscomplete isrefgroup  platformid  devicemodelid  \
# 0       263          2          t          f         200         104110
# 1       254          2          t          f         200         102922
#
#    platformtypeid   osid  adspaceid  premlevel            latestimptime  \
# 0               1  25000       8867        100  2015-11-03 13:38:05.139
# 1               1  25000      10181         50   2015-11-05 09:47:16.51
#
#            earliestimptime  deliveredimp  imp30pct300ms  click  \
# 0  2015-11-03 13:38:03.618             1              1      0
# 1  2015-11-03 12:44:51.541             2              1      0
#
#    1stinteraction  imp0pct0ms  viewtime50pct300ms
# 0               0           1                2920
# 1               0           1                1056

# %%
# check NaN and null values by column
rawData.isnull().any()
# Out:
# surveyid               False
# originaladid           False
# surveyadid             False
# format                 False
# market                 False
# originaladstarttime    False
# originaladendtime      False
# surveyresponcetime     False
# uid                    False
# answersetid            False
# answerid               False
# questionid             False
# questiontext           False
# optionid               False
# optiontext             False
# iscomplete             False
# isrefgroup             False
# platformid             False
# devicemodelid           True
# platformtypeid         False
# osid                   False
# adspaceid              False
# premlevel              False
# latestimptime          False
# earliestimptime        False
# deliveredimp           False
# imp30pct300ms          False
# click                  False
# 1stinteraction         False
# imp0pct0ms             False
# viewtime50pct300ms      True
# dtype: bool

# %%
# check how many null values exist in devicemodelid
print ('no. rows with null deviceModelId :',rawData.devicemodelid.isnull().values.sum())
print ('no. rows with null viewtime50pct300ms :',rawData.devicemodelid.isnull().values.sum())
print ('no. rows and columns in total dataset :',rawData.shape)
# Out:
# ('no. rows with null deviceModelId :', 1025)
# ('no. rows with null viewtime50pct300ms :', 1025)
# ('no. rows and columns in total dataset :', (512114, 31))

# %%
# show 5 random rows of data with devicemodel being null
rawData[rawData.devicemodelid.isnull()].sample(n=5, random_state=0)
# Out:
#         surveyid  originaladid  surveyadid    format market  \
# 428276       487         38864       39452  takeover     FI
# 16715        320         37017       37112  takeover     FR
# 32644        352         36100       37351  takeover     FI
# 360632       438         38798       39010  takeover     NL
# 464646       494         39640       39719  takeover     FI
#
#         originaladstarttime    originaladendtime   surveyresponcetime  \
# 428276  2016-01-13 23:00:00  2016-02-07 21:59:00  2016-01-23 14:42:03
# 16715   2015-11-09 23:00:00  2015-12-27 22:59:00  2015-12-05 07:51:37
# 32644   2015-11-12 23:00:00  2015-12-20 21:59:00  2015-12-17 20:44:38
# 360632  2015-12-22 07:00:00  2016-01-31 22:59:00  2015-12-30 06:07:00
# 464646  2016-01-26 15:15:00  2016-02-19 21:59:00  2016-02-03 12:58:56
#
#                         uid  answersetid  answerid  questionid  \
# 428276  1278836919762939797       371619   1000428          90
# 16715   6115363262446592620       273555    741567          91
# 32644   2494753593507054748       304735    830826          86
# 360632   414074184151369928       336740    916984          86
# 464646  4428159927927460041       390321   1042740          91
#
#                                              questiontext  optionid  \
# 428276                                   How old are you?       284
# 16715                                                I am       290
# 32644   Is the ad interesting for you?<br><span class=...       264
# 360632  Is the ad interesting for you?<br><span class=...       266
# 464646                                               I am       290
#
#        optiontext iscomplete isrefgroup  platformid  devicemodelid  \
# 428276      25-34          t          f         200            NaN
# 16715      Female          t          f         200            NaN
# 32644           3          t          f         200            NaN
# 360632          5          t          t         200            NaN
# 464646     Female          t          f         200            NaN
#
#         platformtypeid   osid  adspaceid  premlevel            latestimptime  \
# 428276               1  25000      13035         80  2016-01-08 16:09:07.954
# 16715                1  25100      12383        100  2015-11-20 11:35:31.737
# 32644                1  24400       9751         80  2015-12-14 08:43:19.632
# 360632               1  24200      10688         50  2015-12-28 13:20:49.689
# 464646               1  25100      11019         80  2015-12-14 19:14:39.974
#
#                 earliestimptime  deliveredimp  imp30pct300ms  click  \
# 428276  2016-01-08 16:09:07.626             1              1      0
# 16715   2015-11-20 11:35:31.737             1              0      0
# 32644   2015-12-11 07:52:36.346             3              1      0
# 360632  2015-12-26 20:50:41.813             3              2      0
# 464646  2015-12-14 19:14:38.784             1              1      0
#
#         1stinteraction  imp0pct0ms  viewtime50pct300ms
# 428276               0           1                9900
# 16715                0           0                 NaN
# 32644                0           2               54515
# 360632               0           3              230107
# 464646               0           1               46888

# %%
# show 5 random rows of data with viewtime being null
rawData[rawData.viewtime50pct300ms.isnull()].sample(n=5, random_state=0)
# Out:
#         surveyid  originaladid  surveyadid    format market  \
# 128083       412         37938       38529  takeover     SE
# 116386       412         35912       38530  takeover     SE
# 37871        370         35335       37913  takeover     UK
# 277877       415         38369       38572  takeover     SE
# 136771       412         37939       38530  takeover     SE
#
#         originaladstarttime    originaladendtime   surveyresponcetime  \
# 128083  2015-12-22 23:00:00  2015-12-27 22:59:00  2015-12-22 12:38:27
# 116386  2015-11-30 23:00:00  2015-12-21 22:59:00  2015-12-15 21:14:37
# 37871   2015-11-25 23:00:00  2015-12-20 22:59:00  2015-12-01 12:22:17
# 277877  2015-12-08 23:00:00  2015-12-24 22:59:00  2015-12-18 21:59:49
# 136771  2015-12-27 23:00:00  2015-12-28 22:59:00  2015-12-20 14:17:15
#
#                         uid  answersetid  answerid  questionid  \
# 128083  5231395000856403394       320933    876429          83
# 116386  1541464092701817227       299066    814461          84
# 37871   8938715974323840301       267021    725310          90
# 277877  6604673828460915347       309286    843756          83
# 136771  4565499719095470341       314355    858776          83
#
#                                              questiontext  optionid  \
# 128083  Next time you are about to use/purchase §categ...       255
# 116386   Have you seen this ad on a mobile device before?       258
# 37871                                    How old are you?       284
# 277877  Next time you are about to use/purchase §categ...       253
# 136771  Next time you are about to use/purchase §categ...       256
#
#        optiontext iscomplete isrefgroup  platformid  devicemodelid  \
# 128083          3          t          f         200         102974
# 116386         No          t          t         100         100000
# 37871       25-34          t          f         100         103010
# 277877          1          t          t         200         103546
# 136771          4          t          t         200         106142
#
#         platformtypeid   osid  adspaceid  premlevel            latestimptime  \
# 128083               1  24400       5791         70  2015-12-18 08:25:39.093
# 116386               1  17100       7511         70  2015-12-15 21:09:39.272
# 37871                1  18400      13544         70  2015-11-25 16:14:09.157
# 277877               1  24400       7529         30  2015-11-10 19:25:39.297
# 136771               1  25000      10424         90  2015-11-27 08:31:42.979
#
#                 earliestimptime  deliveredimp  imp30pct300ms  click  \
# 128083  2015-12-18 08:25:39.093             1              0      0
# 116386  2015-12-15 21:09:39.272             1              0      0
# 37871   2015-11-25 16:14:09.157             1              0      0
# 277877  2015-11-10 19:25:39.297             1              0      0
# 136771  2015-11-27 08:31:42.979             1              0      0
#
#         1stinteraction  imp0pct0ms  viewtime50pct300ms
# 128083               0           0                 NaN
# 116386               0           0                 NaN
# 37871                0           0                 NaN
# 277877               0           0                 NaN
# 136771               0           0                 NaN

# %%
# fill all null values with 0
rawData['viewtime50pct300ms']=rawData.viewtime50pct300ms.fillna(0)
rawData['devicemodelid']=rawData.devicemodelid.fillna(0)
# copy data
df1=rawData.copy()
# check if any data point is null at all
df1.isnull().any().any()
# Out:
# False

# %%
# define url
url_adspace = '/Users/shaokuixing/Desktop/whatever/adspace_apptype_channel.csv'

# read csv file without header
adspace = pd.read_csv(url_adspace, sep=',', thousands = '.', decimal =',')

# show adspace 5 rows
adspace.sample(5)

adspace.shape
# Out:
# (12172, 4)

# %%
import sqlite3
from pandas.io import sql
cnx = sqlite3.connect(':memory:', timeout=3000)
cnx.text_factory = str

# %%
# write to database
sql.to_sql(df1, name = 'df1', con=cnx, if_exists='replace')
sql.to_sql(adspace, name = 'adspace', con=cnx, if_exists='replace')

# %%
# join 2 data sets
df2 = sql.read_sql("select * from df1 d left outer join adspace s on d.adspaceid=s.adspaceid;",cnx)
df2.sample(5)
# Out:
#          index  surveyid  originaladid  surveyadid    format market  \
# 61050    61050       386         36563       38144  takeover     SE
# 208718  208718       415         38360       38572  takeover     SE
# 467903  467903       494         39640       39719  takeover     FI
# 451288  451288       488         39492       39507  takeover     UK
# 433781  433781       488         39439       39507  takeover     UK
#
#         originaladstarttime    originaladendtime   surveyresponcetime  \
# 61050   2015-11-11 23:00:00  2015-12-23 22:59:00  2015-12-12 08:33:18
# 208718  2015-12-08 23:00:00  2015-12-24 22:59:00  2015-12-17 11:50:17
# 467903  2016-01-26 15:15:00  2016-02-19 21:59:00  2016-02-04 01:42:28
# 451288  2016-02-08 23:00:00  2016-02-21 22:59:00  2016-01-30 01:31:56
# 433781  2016-02-09 23:00:00  2016-02-28 22:59:00  2016-01-25 16:11:33
#
#                         uid  answersetid  answerid  questionid  \
# 61050   2556890233898831487       288680    783223          90
# 208718   413881680447976759       303054    825910          83
# 467903  3800840037040497076       391964   1047004          83
# 451288  6497889512902414551       381275   1022383          90
# 433781  2189664497076494566       374230   1006061          86
#
#                                              questiontext  optionid  \
# 61050                                    How old are you?       285
# 208718  Next time you are about to use/purchase §categ...       255
# 467903  Next time you are about to use/purchase §categ...       255
# 451288                                   How old are you?       284
# 433781  Is the ad interesting for you?<br><span class=...       265
#
#        optiontext iscomplete isrefgroup  platformid  devicemodelid  \
# 61050       35-44          t          f         200         100312
# 208718          3          t          t         100         104772
# 467903          3          t          f         200         110586
# 451288      25-34          t          f         200         103362
# 433781          4          t          f         200         100300
#
#         platformtypeid   osid  adspaceid  premlevel            latestimptime  \
# 61050                1  25100       5523         70  2015-11-10 19:26:15.602
# 208718               1  19000       5674         70  2015-12-15 17:42:34.252
# 467903               1  25100       9466         80  2016-01-09 16:36:13.227
# 451288               1  25000      10099         60  2016-01-26 15:49:16.989
# 433781               1  24400      14518         70   2015-11-18 00:10:38.82
#
#                 earliestimptime  deliveredimp  imp30pct300ms  click  \
# 61050   2015-11-10 19:26:06.442             1              1      0
# 208718  2015-12-10 16:16:28.038            10              6      0
# 467903  2016-01-09 16:36:12.687             1              1      0
# 451288  2016-01-20 18:39:27.703             2              2      0
# 433781  2015-11-18 00:07:39.193             2              0      0
#
#         1stinteraction  imp0pct0ms  viewtime50pct300ms  index  adspaceid  \
# 61050                0           0                   0   2902       5523
# 208718               0           6               41012   3031       5674
# 467903               0           1               21310   6187       9466
# 451288               1           2               50428   6806      10099
# 433781               0           0                   0  11160      14518
#
#            apptype apptypegroup             channel
# 61050   MOBILE_WEB   MOBILE_WEB              Family
# 208718  MOBILE_WEB   MOBILE_WEB                News
# 467903  MOBILE_WEB   MOBILE_WEB              Sports
# 451288  MOBILE_WEB   MOBILE_WEB  Gaming/Social Apps
# 433781  MOBILE_WEB   MOBILE_WEB                News

# %%
# check if the joined datasets contain null value
df2.isnull().any().any()
# Out:
# False

# %%
# check number of column and rows of data
df2.shape
# Out:
# (512114, 37)

# %%
# look at all columns vertically
df2.head(1).transpose()
# Out:
#                                                                      0
# index                                                                0
# surveyid                                                           291
# originaladid                                                     36430
# surveyadid                                                       36355
# format                                                           swipe
# market                                                              FI
# originaladstarttime                                2015-11-01 23:00:00
# originaladendtime                                  2015-11-22 22:59:00
# surveyresponcetime                                 2015-11-04 20:31:57
# uid                                                5857845920412998079
# answersetid                                                     218047
# answerid                                                        595092
# questionid                                                          86
# questiontext         Is the ad interesting for you?<br><span class=...
# optionid                                                           263
# optiontext                                                           2
# iscomplete                                                           t
# isrefgroup                                                           f
# platformid                                                         200
# devicemodelid                                                   104110
# platformtypeid                                                       1
# osid                                                             25000
# adspaceid                                                         8867
# premlevel                                                          100
# latestimptime                                  2015-11-03 13:38:05.139
# earliestimptime                                2015-11-03 13:38:03.618
# deliveredimp                                                         1
# imp30pct300ms                                                        1
# click                                                                0
# 1stinteraction                                                       0
# imp0pct0ms                                                           1
# viewtime50pct300ms                                                2920
# index                                                             5608
# adspaceid                                                         8867
# apptype                                                     MOBILE_WEB
# apptypegroup                                                MOBILE_WEB
# channel                                                         Family

# %%
# count rows by format
df2.format.value_counts()
# Out:
# takeover             450351
# swipe                 58514
# tablet_halfscreen      2589
# interstitial            660
# Name: format, dtype: int64

# %%
# select subset based on column values condition OR
# select only takeover and swipe formats
df3=df2.copy()
df3 = df3[(df3.format != 'takeover')|(df3.format != 'swipe')]
df3.sample(5)
# Out:
#          index  surveyid  originaladid  surveyadid    format market  \
# 51416    51416       378         38020       38043     swipe     SE
# 219369  219369       415         38362       38571  takeover     SE
# 327436  327436       422         38597       38713  takeover     FI
# 195566  195566       415         38359       38571  takeover     SE
# 385787  385787       454         39098       39223  takeover     SE
#
#         originaladstarttime    originaladendtime   surveyresponcetime  \
# 51416   2015-12-10 09:00:00  2015-12-24 11:00:00  2015-12-15 20:57:56
# 219369  2015-12-08 23:00:00  2015-12-24 22:59:00  2015-12-17 20:22:15
# 327436  2015-12-06 23:00:00  2016-01-10 21:59:00  2016-01-01 09:38:54
# 195566  2015-12-08 23:00:00  2015-12-24 22:59:00  2015-12-20 07:12:17
# 385787  2016-01-10 23:00:00  2016-01-17 22:59:00  2016-01-20 00:30:54
#
#                         uid  answersetid  answerid  questionid  \
# 51416   4144467508521589890       299027    814307          83
# 219369  5042704927228812263       304662    830546          83
# 327436   922165521373547931       339828    923775          86
# 195566   414081185717611347       313243    855469          84
# 385787   413791728115103718       366066    988137          84
#
#                                              questiontext  optionid  \
# 51416   Next time you are about to use/purchase §categ...       255
# 219369  Next time you are about to use/purchase §categ...       255
# 327436  Is the ad interesting for you?<br><span class=...       264
# 195566   Have you seen this ad on a mobile device before?       258
# 385787   Have you seen this ad on a mobile device before?       258
#
#        optiontext iscomplete isrefgroup  platformid  devicemodelid  \
# 51416           3          t          t         100         102719
# 219369          3          t          f         100         102719
# 327436          3          t          t         200         102922
# 195566         No          t          f         200         102819
# 385787         No          t          f         100         100000
#
#         platformtypeid   osid  adspaceid  premlevel            latestimptime  \
# 51416                1  17100       1947         70  2015-12-01 11:46:30.549
# 219369               1  19100      12988         60  2015-12-15 19:29:56.206
# 327436               1  25000      13434         30  2015-12-15 17:04:21.237
# 195566               1  24200      13083         50   2015-12-18 11:09:09.10
# 385787               1  19000      10423         90  2015-12-22 19:45:32.386
#
#                 earliestimptime  deliveredimp  imp30pct300ms  click  \
# 51416   2015-12-01 11:46:27.746             1              1      0
# 219369  2015-12-15 19:29:55.816             1              1      0
# 327436  2015-12-15 17:04:21.237             1              0      0
# 195566  2015-12-11 09:17:24.848            11              2      0
# 385787  2015-12-22 19:45:30.721             1              1      0
#
#         1stinteraction  imp0pct0ms  viewtime50pct300ms  index  adspaceid  \
# 51416                0           1                6466   1261       1947
# 219369               0           1                9954   9669      12988
# 327436               0           0                   0  10111      13434
# 195566               0           2                3827   9762      13083
# 385787               0           1                5280   7127      10423
#
#            apptype apptypegroup        channel
# 51416   MOBILE_WEB   MOBILE_WEB         Sports
# 219369  IPHONE_APP   MOBILE_APP  Entertainment
# 327436  MOBILE_WEB   MOBILE_WEB          Other
# 195566  MOBILE_WEB   MOBILE_WEB          Other
# 385787  MOBILE_WEB   MOBILE_WEB          Other
